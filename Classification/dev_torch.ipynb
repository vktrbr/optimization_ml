# %%
import torch
from sklearn.datasets import make_classification
from algorithms import LogisticRegressionRBF
import pandas as pd

x, y = make_classification(n_samples=500, n_features=4, random_state=1)
x = torch.FloatTensor(x[:, :2])
y = torch.FloatTensor(y)

# %%
model = LogisticRegressionRBF(x)
model = model.fit(x, y, 1)
# Out:
# Epoch:     1 | CrossEntropyLoss:  0.71911

# %%
metrics = model.metrics_tab(x, y)
tab = pd.DataFrame({'0': metrics['0.0'], '1': metrics['1.0']}).T.round(3)
print(f'Accuracy: {metrics["accuracy"]: 0.2%}')
tab
# Out:
# Accuracy:  43.60%
#    precision  recall  f1-score  support
# 0      0.448   0.597     0.512    248.0
# 1      0.412   0.278     0.332    252.0

# %%
from metrics import roc_curve_plot, auc_roc
y_prob = model(x).detach().cpu().numpy().flatten()
print(f'AUC-ROC: {auc_roc(y, y_prob)}')
roc_curve_plot(y, y_prob, fill=True)
# Out:
# AUC-ROC: 0.515264976958525
# ...
